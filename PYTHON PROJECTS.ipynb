# %% [markdown]
# # Theatre ticket booking system

# %%
#Create Theatre ticket booking system

print("="*15,"Welcome to theatre ticket booking system","="*15)
print()

print("Normal Seat"," "*15,"Recliner Seat"," "*15,"Popcorn Combo")
print("250 Rupees"," "*17,"450 Rupees"," "*18,"200 Rupees")

print()
print("-"*73)


total = 150
normalseat = 140
reclinerseat = 10

popcorn = 200

nprice = 250 
rprice = 450

while True:
    name = input("Customer name: ")
    seats = int(input("How many seats do you prefer?: "))
    
    choice = input("Which seats do you prefer (Normal/Recliner)?: ").lower()
    
    if choice == "normal":
        combo = input("Would you like to add popcorn (yes/no)? ")
        if combo == "yes":
            
            normalseat -= seats
            if normalseat > 0:
                print("-"*40)
                print(name ,"Your total amount with popcorn is: ", (seats*nprice)+popcorn)
                print("Thank You, Visit again!")
                print(normalseat, " seats left")
                print("-"*40)
            else:
                print("Housefull, sorry for the inconvenience :( ")
        else:
            normalseat -= seats
            if normalseat > 0:
                print("-"*40)
                print(name ,"Your total amount is ", seats*nprice)
                print("Thank You, Visit again!")
                print(normalseat, " seats left")
                print("-"*40)
            else:
                print("Housefull, sorry for the inconvenience :( ")
    else:
        combo = input("Would you like to add popcorn (yes/no)? ")
        if combo == "yes":
            reclinerseat -= seats
            if reclinerseat > 0:
                print("-"*40)
                print(name, "Your total amount with popcorn is ",  (seats*rprice)+popcorn)
                print("Thank You, Visit again!")
                print(reclinerseat, " seats left")
                print("-"*40)
            else:
                print("housefull, sorry for the inconvenience :( ")
        else:
            reclinerseat -= seats
            if reclinerseat > 0:
                print("-"*40)
                print(name, "Your total amount is ", seats*nprice)
                print("Thank You, Visit again!")
                print(reclinerseat, " seats left")
                print("-"*40)
            else:
                print("housefull, sorry for the inconvenience :( ")
            
            
    repeat = input("Next person(yes/no)?: ")
    if repeat == "no":
        break
        
        
print("Counter closed")
# Out:
# =============== Welcome to theatre ticket booking system ===============
#
# Normal Seat                 Recliner Seat                 Popcorn Combo
# 250 Rupees                   450 Rupees                    200 Rupees
#
# -------------------------------------------------------------------------
# Customer name: Anish
# How many seats do you prefer?: 139
# Which seats do you prefer (Normal/Recliner)?: normal
# Would you like to add popcorn (yes/no)? yes
# ----------------------------------------
# Anish Your total amount with popcorn is:  34950
# Thank You, Visit again!
# 1  seats left
# ----------------------------------------
# Next person(yes/no)?: yes
# Customer name: Harsh
# How many seats do you prefer?: 2
# Which seats do you prefer (Normal/Recliner)?: normal
# Would you like to add popcorn (yes/no)? yes
# Housefull, sorry for the inconvenience :(
# Next person(yes/no)?: yes
# Customer name: Rahul
# How many seats do you prefer?: 9
# ...
